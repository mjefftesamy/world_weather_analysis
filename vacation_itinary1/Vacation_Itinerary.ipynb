# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID        City Country  Max Temp Current Description      Lat  \
# 0        1  Vila Velha      BR     86.00          few clouds -20.3297
# 1        4  Butaritari      KI     82.31     overcast clouds   3.0707
# 2        6      Kankon      IN     86.00    scattered clouds  15.0167
# 3        8  Nouadhibou      MR     78.80    scattered clouds  20.9310
# 4        9        Poum      NC     77.09       broken clouds -20.2333
#
#         Lng                 Hotel Name
# 0  -40.2925  Quality Suites Vila Velha
# 1  172.7902         Isles Sunset Lodge
# 2   74.0167       Palolem Beach Resort
# 3  -17.0347                  El Medina
# 4  164.0167                Gîte kajeon

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
vacation_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
# 4b. Display the figure
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=abs(max_temp), dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Vila Velha"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Conde"]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Castro"]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "Cidreira"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "Tibagi"]

# %%
vaca1=vacation_df.loc[vacation_df["Country"]=="BR"]
vaca1
# Out:
#      City_ID                      City Country  Max Temp Current Description  \
# 0          1                Vila Velha      BR     86.00          few clouds
# 15        27                     Conde      BR     77.00       broken clouds
# 34        65                    Castro      BR     67.12     overcast clouds
# 63       131                  Cidreira      BR     73.53          few clouds
# 78       161             Alta Floresta      BR     82.40       broken clouds
# 81       165                    Tibagi      BR     75.34       broken clouds
# 84       170                   Ipixuna      BR     80.60       moderate rain
# 104      209           Arraial Do Cabo      BR     82.40          few clouds
# 118      239               Santa Maria      BR     77.00       broken clouds
# 125      257                Guiratinga      BR     88.39           clear sky
# 126      258                 Boa Vista      BR     87.80    scattered clouds
# 127      259              Jacareacanga      BR     74.70     overcast clouds
# 128      260                    Macapa      BR     80.60       moderate rain
# 142      292                  Belmonte      BR     82.40    scattered clouds
# 147      303                     Maues      BR     80.08       broken clouds
# 172      352                 Piacabucu      BR     82.63       broken clouds
# 181      368  Sao Jose Da Coroa Grande      BR     80.69     overcast clouds
# 191      388                 Tamandare      BR     80.15     overcast clouds
# 197      399                Esmeraldas      BR     80.60     overcast clouds
# 205      414               Sao Gabriel      BR     79.00    scattered clouds
# 229      453     Conceicao Do Araguaia      BR     77.00       broken clouds
# 246      478        Sao Felix Do Xingu      BR     77.40     overcast clouds
# 247      482                 Guarapari      BR     86.00          few clouds
# 255      496             Florianopolis      BR     79.00       broken clouds
# 259      500                     Amapa      BR     73.51     overcast clouds
# 264      509             Jequitinhonha      BR     91.18    scattered clouds
# 277      536                     Arcos      BR     80.56    scattered clouds
# 287      555                Carutapera      BR     77.61       moderate rain
# 290      560               Mozarlandia      BR     88.63           clear sky
# 291      561                    Touros      BR     84.20       broken clouds
# 293      566                Rio Grande      BR     77.00    scattered clouds
# 295      569                 Caravelas      BR     84.47    scattered clouds
# 318      631           Barra Do Bugres      BR     90.27       broken clouds
# 321      636                     Natal      BR     84.20       broken clouds
# 341      680                    Papara      BR     84.20       broken clouds
#
#          Lat      Lng                              Hotel Name
# 0   -20.3297 -40.2925               Quality Suites Vila Velha
# 15   -7.2597 -34.9075                      Pousada Beija Flor
# 34  -24.7911 -50.0119                          CHACARA BAILLY
# 63  -30.1811 -50.2056                           Hotel Castelo
# 78   -9.8756 -56.0861                Floresta Amazonica Hotel
# 81  -24.5094 -50.4136              Hotel Formigas na Figueira
# 84   -1.7625 -48.8043                        Casa da Oscarina
# 104 -22.9661 -42.0278                     Pousada Porto Praia
# 118 -29.6842 -53.8069                           Hotel Morotin
# 125 -16.3494 -53.7583  Hotel Angra do Cerrado - Guiratinga MT
# 126   2.8197 -60.6733                      Aipana Plaza Hotel
# 127  -6.2222 -57.7528                            Casa do Ian😎
# 128   0.0389 -51.0664                          Atalanta Hotel
# 142 -15.8631 -38.8828             Pousada Monte Carmelo O Pão
# 147  -3.3836 -57.7186                           Hotel Miramar
# 172 -10.4056 -36.4344                          Piaçabuçu News
# 181  -8.8978 -35.1478                        Crôa Mares Hotel
# 191  -8.7597 -35.1047                      Pousada 100 Passos
# 197 -19.7625 -44.3139              Forasteiro Pousada - Hotel
# 205 -30.3364 -54.3200                             Hotel Obino
# 229  -8.2578 -49.2647                   Tarumã Tropical Hotel
# 246  -6.6447 -51.9950                       Rio Xingu Camping
# 247 -20.6667 -40.4975                      Hotel Porto do Sol
# 255 -27.6146 -48.5012      Hotel Boutique Quinta das Videiras
# 259   1.0000 -52.0000                                     NaN
# 264 -16.4339 -41.0033                        Hotel Bela Vista
# 277 -20.2819 -45.5394                       Hotel Real Palace
# 287  -1.1950 -46.0200                                  Lidera
# 290 -14.7447 -50.5706                      Hotel Santa Mônica
# 291  -5.1989 -35.4608                         INN NEW HORIZON
# 293 -32.0350 -52.0986              Hotel Atlântico Rio Grande
# 295 -17.7125 -39.2481                  Pousada dos Navegantes
# 318 -15.0725 -57.1811                     Hotel 4AM Petrofurt
# 321  -5.7950 -35.2094                Villa Park Hotel | Natal
# 341  -3.9839 -38.7273                                   Romin

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0], vacation_end["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
vacation_itinerary = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')
fig.add_layer(vacation_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID        City Country  Max Temp Current Description      Lat  \
# 0        1  Vila Velha      BR     86.00          few clouds -20.3297
# 1       65      Castro      BR     67.12     overcast clouds -24.7911
# 2      131    Cidreira      BR     73.53          few clouds -30.1811
# 3      165      Tibagi      BR     75.34       broken clouds -24.5094
#
#        Lng                  Hotel Name
# 0 -40.2925   Quality Suites Vila Velha
# 1 -50.0119              CHACARA BAILLY
# 2 -50.2056               Hotel Castelo
# 3 -50.4136  Hotel Formigas na Figueira

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Descriptio</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
vacation_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=vacation_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
